# %% [markdown]
# # Pie Charts
#
# ## Explanation
#
# Pie charts show parts of a whole. Use them only when there are a few categories.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
import matplotlib.pyplot as plt

labels = ['Rent', 'Food', 'Savings']
values = [50, 30, 20]

plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ## Exercises
#
# 1. Create a pie chart for a monthly budget.
# 2. Use autopct to show percentages.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
import matplotlib.pyplot as plt

labels = ['Rent', 'Food', 'Transport', 'Savings']
values = [40, 25, 15, 20]
plt.pie(values, labels=labels, autopct='%1.1f%%')
plt.show()
