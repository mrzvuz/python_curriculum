# %% [markdown]
# # Booleans
#
# ## Explanation
#
# A boolean is either True or False. Booleans are used heavily in conditions, comparisons, and control flow.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
is_python_fun = True
is_snowing = False

print(is_python_fun)
print(10 > 5)
print(3 == 7)
print(bool("hello"))
print(bool(""))

# %% [markdown]
# ## Exercises
#
# 1. Create two boolean variables.
# 2. Print the result of 20 > 10 and 5 == 9.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
is_learning = True
is_finished = False

print(is_learning)
print(is_finished)
print(20 > 10)
print(5 == 9)
