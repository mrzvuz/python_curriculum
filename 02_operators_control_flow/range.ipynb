# %% [markdown]
# # Range
#
# ## Explanation
#
# range() creates a sequence of numbers. It is often used with for loops.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
for number in range(1, 6):
    print(number)

for even_number in range(2, 11, 2):
    print(even_number)

# %% [markdown]
# ## Exercises
#
# 1. Print numbers 1 to 20.
# 2. Print only multiples of 5 from 5 to 50.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
for number in range(1, 21):
    print(number)

for number in range(5, 51, 5):
    print(number)
