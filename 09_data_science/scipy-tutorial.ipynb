# %% [markdown]
# # SciPy Tutorial
#
# ## Explanation
#
# SciPy builds on NumPy and provides scientific tools for optimization, statistics, signal processing, and more.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
import numpy as np
from scipy import stats

scores = np.array([80, 90, 90, 100, 70])
print(stats.describe(scores))

# %% [markdown]
# ## Exercises
#
# 1. Use scipy.stats to describe a list of numbers.
# 2. Calculate a z-score.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
import numpy as np
from scipy import stats

numbers = np.array([10, 20, 30, 40, 50])
print(stats.describe(numbers))
print(stats.zscore(numbers))
