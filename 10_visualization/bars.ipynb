# %% [markdown]
# # Bars
#
# ## Explanation
#
# Bar charts compare categories.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
import matplotlib.pyplot as plt

products = ['A', 'B', 'C']
sales = [30, 50, 20]

plt.bar(products, sales)
plt.show()

# %% [markdown]
# ## Exercises
#
# 1. Create a bar chart of favorite foods.
# 2. Add a title.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
import matplotlib.pyplot as plt

foods = ['Pizza', 'Soup', 'Salad']
votes = [10, 5, 7]
plt.bar(foods, votes)
plt.title('Favorite Foods')
plt.show()
