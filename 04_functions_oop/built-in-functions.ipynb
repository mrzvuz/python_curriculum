# %% [markdown]
# # Built-in Functions
#
# ## Explanation
#
# Built-in functions are always available in Python. Examples include print(), len(), type(), sum(), min(), max(), sorted(), input(), and range().

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
numbers = [10, 4, 7, 20]

print(len(numbers))
print(sum(numbers))
print(min(numbers))
print(max(numbers))
print(sorted(numbers))

# %% [markdown]
# ## Exercises
#
# 1. Use len() on a string.
# 2. Use sum() on a list of numbers.
# 3. Use sorted() on a list.

# %%
# Write your solution here.
string = "hello world!"
numbers = [1, 9, 3, 7]
print(len(string))
print(sum(numbers))
print(sorted(numbers))
print(max(numbers))
print(min(numbers))
# Out:
# 12
# 20
# [1, 3, 7, 9]
# 9
# 1

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
text = "Python"
numbers = [4, 10, 2, 8]

print(len(text))
print(sum(numbers))
print(sorted(numbers))
