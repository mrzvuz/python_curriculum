# %% [markdown]
# # Outputs
#
# ## Explanation
#
# Output means showing information to the user. In Python, the most common output tool is print(). You can print text, numbers, variables, and results of calculations.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
print("Hello, Python!")
name = "Adam"
age = 25
print("Name:", name)
print("Age next year:", age + 1)

# %% [markdown]
# ## Exercises
#
# 1. Print your name.
# 2. Print your city and country.
# 3. Print the result of 10 + 15.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
print("Adam")
print("Istanbul, Turkey")
print(10 + 15)
