# %% [markdown]
# # PIP
#
# ## Explanation
#
# pip installs and manages Python packages. Use it from the terminal, not usually inside Python code.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
# Terminal examples:
# python3 -m pip install requests
# python3 -m pip list
# python3 -m pip freeze > requirements.txt

print("Use pip from your terminal to install packages.")

# %% [markdown]
# ## Exercises
#
# 1. Run python3 -m pip list in the terminal.
# 2. Install a small package such as requests.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
# Run these in the terminal, not inside normal Python code:
# python3 -m pip list
# python3 -m pip install requests

print("After installing, import the package in Python.")
