# %% [markdown]
# # Numbers
#
# ## Explanation
#
# Python has integers for whole numbers, floats for decimal numbers, and complex numbers for advanced math.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
age = 25
price = 19.99
complex_number = 2 + 3j

print(type(age), age)
print(type(price), price)
print(type(complex_number), complex_number)

# %% [markdown]
# ## Exercises
#
# 1. Create two integers and add them.
# 2. Create two floats and multiply them.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
first_integer = 12
second_integer = 8
print(first_integer + second_integer)

first_float = 2.5
second_float = 4.0
print(first_float * second_float)
