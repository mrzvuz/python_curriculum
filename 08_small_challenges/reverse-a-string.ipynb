# %% [markdown]
# # Reverse a String
#
# ## Explanation
#
# Strings can be reversed with slicing. The slice [::-1] means start at the end and move backwards.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
text = "Python"
reversed_text = text[::-1]
print(reversed_text)

# %% [markdown]
# ## Exercises
#
# 1. Reverse your name.
# 2. Create a function that reverses any string.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
name = "Adam"
print(name[::-1])


def reverse_text(text):
    return text[::-1]

print(reverse_text("Python"))
