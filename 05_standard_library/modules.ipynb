# %% [markdown]
# # Modules
#
# ## Explanation
#
# A module is a Python file or library you can import. Modules help organize and reuse code.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
import math
import random

print(math.sqrt(25))
print(random.randint(1, 10))

# %% [markdown]
# ## Exercises
#
# 1. Import math and use ceil().
# 2. Import random and choose a random item from a list.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
import math
import random

print(math.ceil(4.2))
colors = ["red", "green", "blue"]
print(random.choice(colors))
