# %% [markdown]
# # Built-in Modules
#
# ## Explanation
#
# Python includes many built-in modules such as math, random, datetime, json, pathlib, os, sys, statistics, and re.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
import sys
import pathlib
import statistics

print(sys.version)
print(pathlib.Path.cwd())
print(statistics.mean([1, 2, 3]))

# %% [markdown]
# ## Exercises
#
# 1. Import pathlib and print the current folder.
# 2. Import os and print the current working directory.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
import pathlib
import os

print(pathlib.Path.cwd())
print(os.getcwd())
