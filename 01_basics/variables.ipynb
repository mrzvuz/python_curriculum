# %% [markdown]
# # Variables
#
# ## Explanation
#
# Variables are names that store values. A variable can point to text, numbers, booleans, lists, dictionaries, objects, and more.

# %% [markdown]
# ## Example
#
# Run the code cell below and then change the values.

# %%
first_name = "Adam"
age = 25
is_learning = True

print(first_name)
print(age)
print(is_learning)

# %% [markdown]
# ## Exercises
#
# 1. Create variables for your name, age, and favorite language.
# 2. Print all three variables.

# %%
# Write your solution here.

# %% [markdown]
# ## Possible Solution

# %%
# Possible solution
name = "Adam"
age = 25
favorite_language = "Python"

print(name)
print(age)
print(favorite_language)
